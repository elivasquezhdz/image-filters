# %%
# !ffmpeg -f concat -safe 0 -i list.txt  -c:v libx264 -pix_fmt yuv420p -c:a aac QIR.mp4
# Out:
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
# ...

# %%
# !ls q_ir

# %%
# !ffmpeg -f concat -safe 0 -i q3.txt  -c:v libx264 -pix_fmt yuv420p -c:a aac Q3IR.mp4
# Out:
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
# ...
