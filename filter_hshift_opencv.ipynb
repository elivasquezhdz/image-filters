# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import numpy as np
import random

# %%
imgs = os.listdir('imgs')

# %%
i = os.path.join('imgs',random.choices(imgs)[0])

# %%
i
# Out:
# 'imgs/IMG_2828.JPG'

# %%
img_gray = cv2.imread(i,0)
img = cv2.imread(i)
img_rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
img_rgb.shape
# Out:
# (3024, 4032, 3)

# %% [markdown]
# ### Color

# %%
yr = img_rgb.shape[1]

# %%
img_gray = cv2.imread("img.png",0)
img = cv2.imread("img.png")
img_rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
# Out:
# [ WARN:0@723.508] global loadsave.cpp:268 findDecoder imread_('img.png'): can't open/read file: check file path/integrity
# [ WARN:0@723.509] global loadsave.cpp:268 findDecoder imread_('img.png'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[77], line 3
#       1 img_gray = cv2.imread("img.png",0)
#       2 img = cv2.imread("img.png")
# ----> 3 img_rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
#
# error: OpenCV(4.11.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
for c in range(3):
  for x in range(xr):
    pixels2shift = random.randrange(0,20)
    pixels  = np.zeros(pixels2shift)
    #np.insert(img_gray[x],0,pixels)
    img_rgb[x,:,c] = np.insert(img_rgb[x,:,c],0,pixels)[0:xsize]

# %%
plt.imshow(img_rgb)

# %%
plt.imshow(img_rgb)

# %% [markdown]
# ### m c

# %%
img = cv2.imread("img.png")
img_rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
  for x in range(xr):
    pixels2shift = random.randrange(0,20)
    pixels  = np.zeros(pixels2shift)
    #cyan 0,1
    img_rgb[x,:,0] = np.insert(img_rgb[x,:,0],0,pixels)[0:yr]
    img_rgb[x,:,1] = np.insert(img_rgb[x,:,2],0,pixels)[0:yr]
    #magenta 0,2
    pixels  = np.zeros(pixels2shift)
    img_rgb[x,:,0] = np.insert(img_rgb[x,:,0],0,pixels)[0:yr]
    img_rgb[x,:,2] = np.insert(img_rgb[x,:,2],0,pixels)[0:yr]

# %%
plt.imshow(img_rgb)

# %%
plt.imshow(img_rgb)

# %%
img_bgr = cv2.cvtColor(img_rgb,cv2.COLOR_RGB2BGR)

# %%
cv2.imwrite("filtered.png",img_bgr)
# Out:
# True

# %% [markdown]
# ### yrange
